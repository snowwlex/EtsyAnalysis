# %%
import pandas as pd
import numpy as np
import re
import datetime
import geopandas

# %%
df = pd.read_csv("raw_datasets/raw_shops.csv")
df = df.drop_duplicates() # to remove duplicates in case of scrapy run several times

# %%
df.head()
# Out:
#            seller_location    seller_join_date number_of_sales  \
# 0            Jaipur, India  On Etsy since 2018         0 Sales
# 1                        -  On Etsy since 2017       226 Sales
# 2  Soorts-Hossegor, France  On Etsy since 2017        14 Sales
# 3                        -  On Etsy since 2019         0 Sales
# 4                        -  On Etsy since 2019         0 Sales
#
#    number_of_admirers number_of_reviews average_review_score  \
# 0                 NaN                 -                    -
# 1                 NaN              (12)                    5
# 2                 NaN               (2)                    4
# 3                 NaN                 -                    -
# 4                 NaN                 -                    -
#
#    date_of_last_review_left  number_of_items
# 0                       NaN                2
# 1                       NaN                3
# 2                       NaN                0
# 3                       NaN                2
# 4                       NaN                9

# %%
df = df.drop(columns=['number_of_admirers','date_of_last_review_left'])
df.head()
# Out:
#            seller_location    seller_join_date number_of_sales  \
# 0            Jaipur, India  On Etsy since 2018         0 Sales
# 1                        -  On Etsy since 2017       226 Sales
# 2  Soorts-Hossegor, France  On Etsy since 2017        14 Sales
# 3                        -  On Etsy since 2019         0 Sales
# 4                        -  On Etsy since 2019         0 Sales
#
#   number_of_reviews average_review_score  number_of_items
# 0                 -                    -                2
# 1              (12)                    5                3
# 2               (2)                    4                0
# 3                 -                    -                2
# 4                 -                    -                9

# %%
def update_nan(value):
    if value == '-':
        return np.nan
    if value == '':
        return np.nan
    return value

df = df.applymap(update_nan)
df.head()
# Out:
#            seller_location    seller_join_date number_of_sales  \
# 0            Jaipur, India  On Etsy since 2018         0 Sales
# 1                      NaN  On Etsy since 2017       226 Sales
# 2  Soorts-Hossegor, France  On Etsy since 2017        14 Sales
# 3                      NaN  On Etsy since 2019         0 Sales
# 4                      NaN  On Etsy since 2019         0 Sales
#
#   number_of_reviews average_review_score  number_of_items
# 0               NaN                  NaN                2
# 1              (12)                    5                3
# 2               (2)                    4                0
# 3               NaN                  NaN                2
# 4               NaN                  NaN                9

# %%
def clean_join_date(seller_join_date):
    pattern = '^On Etsy since ([0-9]+)$'
    res = re.match(pattern, seller_join_date)
    return res.group(1)
    return seller_join_date
    
def clean_number_of_sales(number_of_sales):
    pattern = '^([0-9]+) Sale'
    res = re.match(pattern, number_of_sales)
    return res.group(1)

def clean_number_of_reviews(number_of_reviews):
    pattern = '^\(([0-9]+)\)$'
    res = re.match(pattern, number_of_reviews)
    if res:
        return res.group(1)
    return np.nan

df['seller_join_date'] = df['seller_join_date'].map(clean_join_date, na_action='ignore')
df['number_of_sales'] = df['number_of_sales'].map(clean_number_of_sales, na_action='ignore')
df['number_of_reviews'] = df['number_of_reviews'].map(clean_number_of_reviews, na_action='ignore')
df.head()
# Out:
#            seller_location seller_join_date number_of_sales number_of_reviews  \
# 0            Jaipur, India             2018               0               NaN
# 1                      NaN             2017             226                12
# 2  Soorts-Hossegor, France             2017              14                 2
# 3                      NaN             2019               0               NaN
# 4                      NaN             2019               0               NaN
#
#   average_review_score  number_of_items
# 0                  NaN                2
# 1                    5                3
# 2                    4                0
# 3                  NaN                2
# 4                  NaN                9

# %%
df[df['average_review_score'] == '0'].head()
# Out:
#               seller_location seller_join_date number_of_sales  \
# 10           Montreal, Canada             2015               1
# 15      Oregon, United States             2013               4
# 17                        NaN             2015              77
# 18  California, United States             2015               1
# 21                        NaN             2013               3
#
#    number_of_reviews average_review_score  number_of_items
# 10                 1                    0                0
# 15                 2                    0                0
# 17                 1                    0                0
# 18                 1                    0                0
# 21                 1                    0                0

# %%
# 0 actually means that Etsy just does not show the it - so make it NaN as well
df.loc[ (df['average_review_score'] == '0'), 'average_review_score'] = np.nan

# %%
df.to_csv('datasets/shops.csv', index=False)

# %%
def parse_location(location):
    splitted = location.split(",")
    if len(splitted) == 3:
        return (splitted[0].strip(), splitted[2].strip())
    elif len(splitted) == 2:
        return (splitted[0].strip(), splitted[1].strip())
    return (np.nan, splitted[0].strip())
    
def get_town(location):
    (town, country) = parse_location(location)
    return town

def get_country(location):
    (town, country) = parse_location(location)
    return country

df['seller_town'] = df['seller_location'].map(get_town, na_action='ignore')
df['seller_country'] = df['seller_location'].map(get_country, na_action='ignore')
df.head()
# Out:
#            seller_location seller_join_date number_of_sales number_of_reviews  \
# 0            Jaipur, India             2018               0               NaN
# 1                      NaN             2017             226                12
# 2  Soorts-Hossegor, France             2017              14                 2
# 3                      NaN             2019               0               NaN
# 4                      NaN             2019               0               NaN
#
#   average_review_score  number_of_items      seller_town seller_country
# 0                  NaN                2           Jaipur          India
# 1                    5                3              NaN            NaN
# 2                    4                0  Soorts-Hossegor         France
# 3                  NaN                2              NaN            NaN
# 4                  NaN                9              NaN            NaN

# %%
df.to_csv('datasets/shops_add.csv', index=False)

# %%
## prepare geocodes
wc = pd.read_csv("raw_datasets/worldcities.csv") # taken from https://www.kaggle.com/juanmah/world-cities
wc = wc[['city', 'country', 'lat', 'lng']]
wc['index'] = wc['city'] + ", " + wc['country']
wc.head()
# Out:
#           city country      lat      lng                index
# 0    Malishevë  Kosovo  42.4822  20.7458    Malishevë, Kosovo
# 1      Prizren  Kosovo  42.2139  20.7397      Prizren, Kosovo
# 2  Zubin Potok  Kosovo  42.9144  20.6897  Zubin Potok, Kosovo
# 3     Kamenicë  Kosovo  42.5781  21.5803     Kamenicë, Kosovo
# 4         Viti  Kosovo  42.3214  21.3583         Viti, Kosovo

# %%
#get geocodes for States

# commented, as asking Nominatim takes some time
# states = geocodes[ geocodes['seller_country'] == 'United States']['seller_town'].drop_duplicates().dropna()
# states_geo = geopandas.tools.geocode(states.to_list(), provider='nominatim', user_agent="snowwlex-app")
# states_df = pd.DataFrame({
#     'state_name' : states.to_list(),
#     'lng' : states_geo['geometry'].apply(lambda p: p.x),
#     'lat' : states_geo['geometry'].apply(lambda p: p.y)
# })
# states_df.to_csv('datasets/states_geocodes.csv', index=False)

# so just load
states_df = pd.read_csv("datasets/states_geocodes.csv")
states_df['index'] = states_df['state_name'] + ", United States"
# us_geocodes_joined = geocodes.set_index('index').join(states_df.set_index('index'), how='inner')

# %%
#combine World Cities with States-specific data:
# as for US, it's state what is specified as 'city'
geo_locations = wc[ wc['country'] != 'United States' ][['index', 'lat', 'lng']].append(states_df[['index', 'lat', 'lng']])

# %%
locations = df[['seller_location', 'seller_country', 'seller_town']].drop_duplicates().dropna(subset=['seller_location'])
locations.head()
# Out:
#            seller_location seller_country      seller_town
# 0            Jaipur, India          India           Jaipur
# 2  Soorts-Hossegor, France         France  Soorts-Hossegor
# 5   Arizona, United States  United States          Arizona
# 8   Milton Keynes, England        England    Milton Keynes
# 9  New York, United States  United States         New York

# %%
locations[ locations['seller_country'] == 'United States'].head()
# Out:
#             seller_location seller_country seller_town
# 5    Arizona, United States  United States     Arizona
# 9   New York, United States  United States    New York
# 12  Illinois, United States  United States    Illinois
# 13  Oklahoma, United States  United States    Oklahoma
# 14      Ohio, United States  United States        Ohio

# %%
#Uniting the United Kingdom
locations.loc[(locations['seller_country'] == 'England'), 'seller_country'] = 'United Kingdom'
locations.loc[(locations['seller_country'] == 'Wales'), 'seller_country'] = 'United Kingdom'
locations.loc[(locations['seller_country'] == 'Scotland'), 'seller_country'] = 'United Kingdom'
locations.loc[(locations['seller_country'] == 'Northern Ireland'), 'seller_country'] = 'United Kingdom'

locations['index'] = locations['seller_town'] + ", " + locations['seller_country']
locations.head()
# Out:
#            seller_location  seller_country      seller_town  \
# 0            Jaipur, India           India           Jaipur
# 2  Soorts-Hossegor, France          France  Soorts-Hossegor
# 5   Arizona, United States   United States          Arizona
# 8   Milton Keynes, England  United Kingdom    Milton Keynes
# 9  New York, United States   United States         New York
#
#                            index
# 0                  Jaipur, India
# 2        Soorts-Hossegor, France
# 5         Arizona, United States
# 8  Milton Keynes, United Kingdom
# 9        New York, United States

# %%
locations_joined = locations.set_index('index').join(geo_locations.set_index('index'), how='inner')
locations_joined[ locations_joined['seller_country'] == 'United Kingdom'].sample(n=10)
# Out:
#                                              seller_location  seller_country  \
# index
# Camberwell, United Kingdom               Camberwell, England  United Kingdom
# Knowsley, United Kingdom                   Knowsley, England  United Kingdom
# Forfar, United Kingdom                      Forfar, Scotland  United Kingdom
# Ipswich, United Kingdom                     Ipswich, England  United Kingdom
# Enniskillen, United Kingdom    Enniskillen, Northern Ireland  United Kingdom
# Shrewsbury, United Kingdom               Shrewsbury, England  United Kingdom
# Milton Keynes, United Kingdom         Milton Keynes, England  United Kingdom
# Haddington, United Kingdom              Haddington, Scotland  United Kingdom
# Torquay, United Kingdom                     Torquay, England  United Kingdom
# Belfast, United Kingdom            Belfast, Northern Ireland  United Kingdom
#
#                                  seller_town      lat     lng
# index
# Camberwell, United Kingdom        Camberwell  51.4736 -0.0916
# Knowsley, United Kingdom            Knowsley  53.4500 -2.8500
# Forfar, United Kingdom                Forfar  56.6500 -2.8833
# Ipswich, United Kingdom              Ipswich  52.0703  1.1700
# Enniskillen, United Kingdom      Enniskillen  54.3466 -7.6411
# Shrewsbury, United Kingdom        Shrewsbury  52.7167 -2.7333
# Milton Keynes, United Kingdom  Milton Keynes  52.0333 -0.7000
# Haddington, United Kingdom        Haddington  55.9333 -2.7667
# Torquay, United Kingdom              Torquay  50.4500 -3.5000
# Belfast, United Kingdom              Belfast  54.5968 -5.9254

# %%
locations_joined[ locations_joined['seller_country'] == 'United States'].sample(n=10)
# Out:
#                                            seller_location seller_country  \
# index
# Delaware, United States            Delaware, United States  United States
# Maryland, United States            Maryland, United States  United States
# Oregon, United States                Oregon, United States  United States
# Georgia, United States              Georgia, United States  United States
# Kentucky, United States            Kentucky, United States  United States
# Massachusetts, United States  Massachusetts, United States  United States
# Pennsylvania, United States    Pennsylvania, United States  United States
# Minnesota, United States          Minnesota, United States  United States
# Alabama, United States              Alabama, United States  United States
# Virginia, United States            Virginia, United States  United States
#
#                                 seller_town        lat         lng
# index
# Delaware, United States            Delaware  38.692045  -75.401331
# Maryland, United States            Maryland  39.516223  -76.938207
# Oregon, United States                Oregon  43.979280 -120.737257
# Georgia, United States              Georgia  32.329381  -83.113737
# Kentucky, United States            Kentucky  37.572603  -85.155141
# Massachusetts, United States  Massachusetts  42.378877  -72.032366
# Pennsylvania, United States    Pennsylvania  40.969989  -77.727883
# Minnesota, United States          Minnesota  45.989659  -94.611329
# Alabama, United States              Alabama  33.258882  -86.829534
# Virginia, United States            Virginia  37.123224  -78.492772

# %%
locations_joined[ locations_joined['seller_country'] == 'United States']
# Out:
#                                                seller_location seller_country  \
# index
# Alabama, United States                  Alabama, United States  United States
# Alaska, United States                    Alaska, United States  United States
# Arizona, United States                  Arizona, United States  United States
# Arkansas, United States                Arkansas, United States  United States
# California, United States            California, United States  United States
# Colorado, United States                Colorado, United States  United States
# Connecticut, United States          Connecticut, United States  United States
# Delaware, United States                Delaware, United States  United States
# Florida, United States                  Florida, United States  United States
# Georgia, United States                  Georgia, United States  United States
# Hawaii, United States                    Hawaii, United States  United States
# Idaho, United States                      Idaho, United States  United States
# Illinois, United States                Illinois, United States  United States
# Indiana, United States                  Indiana, United States  United States
# Iowa, United States                        Iowa, United States  United States
# Kansas, United States                    Kansas, United States  United States
# Kentucky, United States                Kentucky, United States  United States
# Louisiana, United States              Louisiana, United States  United States
# Maine, United States                      Maine, United States  United States
# Maryland, United States                Maryland, United States  United States
# Massachusetts, United States      Massachusetts, United States  United States
# Michigan, United States                Michigan, United States  United States
# Minnesota, United States              Minnesota, United States  United States
# Mississippi, United States          Mississippi, United States  United States
# Missouri, United States                Missouri, United States  United States
# Montana, United States                  Montana, United States  United States
# Nebraska, United States                Nebraska, United States  United States
# Nevada, United States                    Nevada, United States  United States
# New Hampshire, United States      New Hampshire, United States  United States
# New Jersey, United States            New Jersey, United States  United States
# New Mexico, United States            New Mexico, United States  United States
# New York, United States                New York, United States  United States
# North Carolina, United States    North Carolina, United States  United States
# North Dakota, United States        North Dakota, United States  United States
# Ohio, United States                        Ohio, United States  United States
# Oklahoma, United States                Oklahoma, United States  United States
# Oregon, United States                    Oregon, United States  United States
# Pennsylvania, United States        Pennsylvania, United States  United States
# Rhode Island, United States        Rhode Island, United States  United States
# South Carolina, United States    South Carolina, United States  United States
# South Dakota, United States        South Dakota, United States  United States
# Tennessee, United States              Tennessee, United States  United States
# Texas, United States                      Texas, United States  United States
# Utah, United States                        Utah, United States  United States
# Vermont, United States                  Vermont, United States  United States
# Virginia, United States                Virginia, United States  United States
# Washington, United States            Washington, United States  United States
# Washington, United States      Washington, D.C., United States  United States
# West Virginia, United States      West Virginia, United States  United States
# Wisconsin, United States              Wisconsin, United States  United States
# Wyoming, United States                  Wyoming, United States  United States
#
#                                   seller_town        lat         lng
# index
# Alabama, United States                Alabama  33.258882  -86.829534
# Alaska, United States                  Alaska  64.445961 -149.680909
# Arizona, United States                Arizona  34.395342 -111.763275
# Arkansas, United States              Arkansas  35.204888  -92.447911
# California, United States          California  36.701463 -118.755997
# Colorado, United States              Colorado  38.725178 -105.607717
# Connecticut, United States        Connecticut  41.650020  -72.734216
# Delaware, United States              Delaware  38.692045  -75.401331
# Florida, United States                Florida  27.756767  -81.463983
# Georgia, United States                Georgia  32.329381  -83.113737
# Hawaii, United States                  Hawaii  21.216044 -157.975203
# Idaho, United States                    Idaho  43.644764 -114.015407
# Illinois, United States              Illinois  40.079661  -89.433729
# Indiana, United States                Indiana  40.327013  -86.174693
# Iowa, United States                      Iowa  41.921673  -93.312270
# Kansas, United States                  Kansas  38.273120  -98.582187
# Kentucky, United States              Kentucky  37.572603  -85.155141
# Louisiana, United States            Louisiana  30.870388  -92.007126
# Maine, United States                    Maine  45.709097  -68.859020
# Maryland, United States              Maryland  39.516223  -76.938207
# Massachusetts, United States    Massachusetts  42.378877  -72.032366
# Michigan, United States              Michigan  43.621195  -84.682435
# Minnesota, United States            Minnesota  45.989659  -94.611329
# Mississippi, United States        Mississippi  32.971564  -89.734850
# Missouri, United States              Missouri  38.760481  -92.561787
# Montana, United States                Montana  47.375267 -109.638758
# Nebraska, United States              Nebraska  41.737023  -99.587382
# Nevada, United States                  Nevada  39.515883 -116.853723
# New Hampshire, United States    New Hampshire  43.484913  -71.655399
# New Jersey, United States          New Jersey  40.075738  -74.404162
# New Mexico, United States          New Mexico  34.570817 -105.993007
# New York, United States              New York  40.712728  -74.006015
# North Carolina, United States  North Carolina  35.672964  -79.039292
# North Dakota, United States      North Dakota  47.620146 -100.540737
# Ohio, United States                      Ohio  40.225357  -82.688140
# Oklahoma, United States              Oklahoma  34.955082  -97.268406
# Oregon, United States                  Oregon  43.979280 -120.737257
# Pennsylvania, United States      Pennsylvania  40.969989  -77.727883
# Rhode Island, United States      Rhode Island  41.796241  -71.599237
# South Carolina, United States  South Carolina  33.687439  -80.436374
# South Dakota, United States      South Dakota  44.647176 -100.348761
# Tennessee, United States            Tennessee  35.773008  -86.282008
# Texas, United States                    Texas  31.816038  -99.512099
# Utah, United States                      Utah  39.422519 -111.714358
# Vermont, United States                Vermont  44.599072  -72.500261
# Virginia, United States              Virginia  37.123224  -78.492772
# Washington, United States          Washington  38.894893  -77.036553
# Washington, United States          Washington  38.894893  -77.036553
# West Virginia, United States    West Virginia  38.475841  -80.840842
# Wisconsin, United States            Wisconsin  44.430898  -89.688464
# Wyoming, United States                Wyoming  43.170026 -107.568535

# %%
all_locations = locations_joined.reset_index()[['seller_location', 'lng', 'lat']]
all_locations.head()
# Out:
#       seller_location      lng      lat
# 0    Aalborg, Denmark   9.9166  57.0337
# 1  Aarau, Switzerland   8.0524  47.3896
# 2  Aarau, Switzerland   8.0340  47.3900
# 3      Abakan, Russia  91.4450  53.7037
# 4       Abaza, Russia  90.0954  52.6690

# %%
all_locations.to_csv('datasets/all_locations.csv', index=False)
